# %% [markdown]
# <a href="https://colab.research.google.com/github/MridulMahaj/DBMS/blob/main/PRODIGY_DS_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt


iris = sns.load_dataset('iris')


print(iris.head())

# Categorical Variable
plt.figure(figsize=(8, 6))
sns.countplot(x='species', data=iris)
plt.title('Count Plot of Iris Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#Box Plot
plt.figure(figsize=(10, 8))
sns.boxplot(x='species', y='petal_length', data=iris)
plt.title('Box Plot of Petal Length by Iris Species')
plt.xlabel('Species')
plt.ylabel('Petal Length')
plt.tight_layout()
plt.show()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
